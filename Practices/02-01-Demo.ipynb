# %% [markdown]
# <h2><u>Predictive Analystics</u></h2>
#
# # Module 2 – Probability
# <h2> EnCare Bank Demo on Marginal, Joint and Conditional Probability </h2>

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Load Dataset**

# %%
data = pd.read_csv('term_deposit.csv')
print(data.shape)
data.head()
# Out:
# (41188, 10)
#    gender  age        job  marital    education default housing loan  \
# 0  female   56  housemaid  married     basic.4y      no      no   no
# 1    male   57   services  married  high.school     yes      no   no
# 2  female   37   services  married  high.school      no     yes   no
# 3  female   40     admin.  married     basic.6y      no      no   no
# 4  female   56   services  married  high.school      no      no  yes
#
#      contact term_deposit
# 0  telephone           no
# 1  telephone           no
# 2  telephone           no
# 3  telephone           no
# 4  telephone           no

# %%
data.dtypes
# Out:
# gender          object
# age              int64
# job             object
# marital         object
# education       object
# default         object
# housing         object
# loan            object
# contact         object
# term_deposit    object
# dtype: object

# %%
data.describe()
# Out:
#                age
# count  41188.00000
# mean      40.02406
# std       10.42125
# min       17.00000
# 25%       32.00000
# 50%       38.00000
# 75%       47.00000
# max       98.00000

# %%
data.describe(include='O')
# Out:
#         gender     job  marital          education default housing   loan  \
# count    41188   41188    41188              41188   41188   41188  41188
# unique       2      12        4                  8       2       2      2
# top     female  admin.  married  university.degree      no     yes     no
# freq     20798   10422    24928              12168   32588   22566  33950
#
#          contact term_deposit
# count      41188        41188
# unique         2            2
# top     cellular           no
# freq       26144        36548

# %%
data.job.value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### Marginal Probability

# %% [markdown]
# #### Q1. Find the probability that the customer will take the term deposit

# %%
data.term_deposit.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
S = data.shape[0]
print('Total number of customers: ', S)
# Out:
# Total number of customers:  41188

# %%
E = data[data.term_deposit == 'yes'].shape[0]
print('total number of customers who have taken term deposits', E)
# Out:
# total number of customers who have taken term deposits 4640

# %%
p = round(E/S, 3)
print('Probability of a customer taking term_deposit : ', p)
# Out:
# Probability of a customer taking term_deposit :  0.113

# %% [markdown]
# #### Q2. Find the probability that a customer has at least 9 year of basic education.

# %%
data.head()
# Out:
#    gender  age        job  marital    education default housing loan  \
# 0  female   56  housemaid  married     basic.4y      no      no   no
# 1    male   57   services  married  high.school     yes      no   no
# 2  female   37   services  married  high.school      no     yes   no
# 3  female   40     admin.  married     basic.6y      no      no   no
# 4  female   56   services  married  high.school      no      no  yes
#
#      contact term_deposit
# 0  telephone           no
# 1  telephone           no
# 2  telephone           no
# 3  telephone           no
# 4  telephone           no

# %%
data.education.unique()
# Out:
# array(['basic.4y', 'high.school', 'basic.6y', 'basic.9y',
#        'professional.course', 'unknown', 'university.degree',
#        'illiterate'], dtype=object)

# %%
S = data.shape[0]
print('Total number of customers: ', S)
# Out:
# Total number of customers:  41188

# %%
data.education.value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
E = 12168 + 9515 + 6045 + 5243
print('Total no. of customers who have at least 9 year education:', E)
# Out:
# Total no. of customers who have at least 9 year education: 32971

# %%
p = round(E/S, 3)
print('Probability of customer having at least 9 year education:', p )
# Out:
# Probability of customer having at least 9 year education: 0.801

# %% [markdown]
# #### Q3. Find the probability that a customer is technician.

# %%
data.job.unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', 'unknown',
#        'entrepreneur', 'student'], dtype=object)

# %%
data.job.value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
# E -> number of technicials
E = data[data.job == 'technician'].shape[0]
S = data.shape[0]
print("Probability that a customer is technician:", round(E/S, 3))
# Out:
# Probability that a customer is technician: 0.164

# %% [markdown]
# ### Joint Probability

# %% [markdown]
# #### Q1. Find the probability for a male customer who has already taken term deposit.

# %%
S = data.shape[0]
print('Total number of customers: ', S)
# Out:
# Total number of customers:  41188

# %%
pd.crosstab(data.gender, data.term_deposit, margins=True)
# Out:
# term_deposit     no   yes    All
# gender
# female        18442  2356  20798
# male          18106  2284  20390
# All           36548  4640  41188

# %%
E = 2284
p = round(E/S, 3)
print('Total no. of male customers who have taken term_deposit:', E)
print('Probability a customer is male and has taken a term_deposit:', p)
# Out:
# Total no. of male customers who have taken term_deposit: 2284
# Probability a customer is male and has taken a term_deposit: 0.055

# %% [markdown]
# #### Q2. Probability that a customer is married and has housing as well

# %%
data.head()
# Out:
#    gender  age        job  marital    education default housing loan  \
# 0  female   56  housemaid  married     basic.4y      no      no   no
# 1    male   57   services  married  high.school     yes      no   no
# 2  female   37   services  married  high.school      no     yes   no
# 3  female   40     admin.  married     basic.6y      no      no   no
# 4  female   56   services  married  high.school      no      no  yes
#
#      contact term_deposit
# 0  telephone           no
# 1  telephone           no
# 2  telephone           no
# 3  telephone           no
# 4  telephone           no

# %%
S = data.shape[0]
print('Total number of customers: ', S)
# Out:
# Total number of customers:  41188

# %%
data.columns
# Out:
# Index(['gender', 'age', 'job', 'marital', 'education', 'default', 'housing',
#        'loan', 'contact', 'term_deposit'],
#       dtype='object')

# %%
pd.crosstab(data.marital, data.housing, margins=True)
# Out:
# housing      no    yes    All
# marital
# divorced   2092   2520   4612
# married   11389  13539  24928
# single     5097   6471  11568
# unknown      44     36     80
# All       18622  22566  41188

# %%
E = 13539
p = round(E/S, 2)
print('Probability that a customer is married and has taken a housing :',p)
# Out:
# Probability that a customer is married and has taken a housing : 0.33

# %% [markdown]
# #### Q3. Probability that a customer has university degree and no loan

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Conditional Probability

# %% [markdown]
# #### Q1. Given that  customer has taken term deposit, find the probability that she is a female.

# %%
S = data.shape[0]
print('Total number of customers: ', S)

# %%
pd.crosstab(data.gender, data.term_deposit, margins=True)

# %%
# P(customer is a female | customer has taken a term deposit)
A = 20798
B = 4640
AnB = 2356
print('Number of female customers: P(A)', A)
print('Number of customer who have taken term deposit P(B):', B)
print('Customer is female and has taken term deposit: P(A&B)', AnB)

# %%
pAnB = round(AnB/S,3)
pB = round(B/S, 3)
print('Joint probability that a customer is female has has taken term deposit:', pAnB )
print('Marginal probability that a customer has taken term deposit:', pB)

# %%
# P(A | B) = P(A and B) / P(B)
pAgivenB = round(pAnB/pB, 3)
print('Conditional probability the customer is a female GIVEN customer has taken term deposit:',pAgivenB)

# %%
2356/4640

# %% [markdown]
# #### Q2. Given that selected customer has defaulted in past, find the probability that he/she has a blue collar job.

# %%
pd.crosstab(data.job, data.default, margins=True)

# %%
3166/8600

# %%
# P(customer has blue collar job | customer has defaulted in the past)
A = 9254
B = 8600
AnB = 3166
print('Number of cusotmer with blue collar job:', A)
print('Number of customers defaulted in the past:', B)
print('Number of customers with blue collar job AND customers defaulted in past:', AnB)

# %%
pAnB = round(AnB/S,3)
pB = round(B/S, 3)
print('Joint probability that a customer has blue collar job AND customers defaulted in past:', pAnB )
print('Marginal probability that a customer has defaulted in the past:', pB)

# %%
# P(A | B) = P(A and B) / P(B)
pAgivenB = round(pAnB/pB, 3)
print('Conditional probability that the customer has blue collar job GIVEN customer has defaulted:',pAgivenB)
