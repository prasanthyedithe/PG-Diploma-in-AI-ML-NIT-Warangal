# %% [markdown]
# # Computer Vision using OpenCV

# %% [markdown]
# # Installation

# %%
# !pip install opencv-python

# %% [markdown]
# # Face detection using opencv

# %%
import cv2
# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
# testImage = 'download123.jpg'
testImage = 'fake_ai_faces.0.png'
# testImage = 'celebrity-faces.jpg'
# testImage = 'multiple-faces.jpg'
cameraId = 1

# %%
# Read the input image
img = cv2.imread(testImage)
# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)
# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255), 2)
# Display the output
cv2.imshow('img', img)
#cv2.waitKey()
cv2.waitKey(0)
cv2.destroyAllWindows()
# when the dialog with image pops up, don't close it using the 'x' button, press any key to close it
# cv2 needs to destroy all windows so that it does not clash with Jupyter Notebook

# %% [markdown]
# # Video capturing using OpenCV

# %%
import cv2,time
cameraId = 1
video=cv2.VideoCapture(cameraId)
#create VideoCapture object to trigger the camera
# 0’ is to specify that use built-in camera
if (video.isOpened() == False):
    print("Unable to read camera feed")
else:
    check , frame = video.read()
    print(check, type(frame), frame.shape)
    #print(frame)
    time.sleep(3) # will stop the script for 3 seconds
    video.release()
    # cv2.imshow('img',frame)
    # cv2.waitKey(0)
    #This will release the camera in some milliseconds
    cv2.destroyAllWindows()
# Out:
# True <class 'numpy.ndarray'> (480, 640, 3)

# %% [markdown]
# # video capturing using OpenCv

# %%
import cv2,time
video=cv2.VideoCapture(cameraId)

a = 1

while True:
    a=a+1
    check, frame = video.read()
    #print(frame)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    predict(frame)
    cv2.imshow('capturing',frame)

    key = cv2.waitKey(1)

    if key == ord('q'):
        break

#print(a)
video.release()
cv2.destroyAllWindows()

# %% [markdown]
# # detecting face in video using OpenCv

# %%
def faceDetect(img):


    # Convert into grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    # Draw rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    # Display the output
    cv2.imshow('img', img)
    #cv2.waitKey()
    #cv2.waitKey(0)

# %%
import cv2,time

# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
video=cv2.VideoCapture(cameraId)

a = 1

while True:
    a=a+1
    check, frame = video.read()
    #print(frame)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faceDetect(frame)
    #cv2.imshow('capturing',frame)
    key = cv2.waitKey(1)

    if key == ord('q'):
        break

#print(a)
video.release()
cv2.destroyAllWindows()
