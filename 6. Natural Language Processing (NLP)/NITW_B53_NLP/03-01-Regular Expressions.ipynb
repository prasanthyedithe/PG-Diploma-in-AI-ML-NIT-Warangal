# %%
import re

# %%
# dir(re)

# %%
# help(re)

# %%
mystr = '0'

# %%
print(re.search('[a-z][0-9][0-9]', 'foo1x23bar'))
# Out:
# <re.Match object; span=(4, 7), match='x23'>

# %%
print(re.findall('[0-9]+', '234bazyfejgkou9ejfj8477566556ofakjfhj'))
# Out:
# ['234', '9', '8477566556']

# %%
print(re.search('[0-9][0-9][a-z]', '234bazyfejgkou9ejfj8477566556ofakjfhj'))
# Out:
# <re.Match object; span=(1, 4), match='34b'>

# %%
print(re.findall('[0-9][0-9][a-z]', '234bazyfejgkou9ejfj8477566556ofakjfhj'))
# Out:
# ['34b', '56o']

# %%
print(re.search('[0-9][0-9][0-9]', '12foo34'))
# Out:
# None

# %%
print(re.search('[A-Z][0-9][0-9]', '12foo34'))
# Out:
# None

# %%
mystring = 'Here is an absolute ab string'
print(re.search('ab', mystring))
print(re.findall('ab', mystring))
# Out:
# <re.Match object; span=(11, 13), match='ab'>
# ['ab', 'ab']

# %%
mystring = 'Here is an absolute ab string'
print(re.match('He', mystring))
print(re.match('ab', mystring))
print(re.search('ab', mystring))
# Out:
# <re.Match object; span=(0, 2), match='He'>
# None
# <re.Match object; span=(11, 13), match='ab'>

# %%
# print(re.match('ab', 'absolutely there is a match here'))
print(re.findall('ab', 'Here is an absolute string with another absolute and what about nothing'))
# Out:
# ['ab', 'ab', 'ab']

# %%
import re
print(re.sub('[ac]', '*', 'abcde abcdef abcdef'))
# Out:
# *b*de *b*def *b*def

# %%
import re
print(re.sub('[ad][bc]', '*', 'abcde abcdef abcdef'))
# Out:
# *cde *cdef *cdef

# %%
import re
print(re.findall('ab', 'abcde abcdef abcdef'))
# Out:
# ['ab', 'ab', 'ab']

# %%
print(re.sub('abc', '*', 'abde abcdef abcdef' ))
# chr r in the sub function signifies that the string following is without escape character
# Out:
# abde *def *def

# %%
mystring = 'Hi Ram, Welcome to Edureka'
print(re.findall('[a-zA-Z]+', mystring))
# Out:
# ['Hi', 'Ram', 'Welcome', 'to', 'Edureka']

# %%
mystring = 'Hi Ram, Welcome to Edureka'
print(re.findall('[a-zA-Z]+', mystring))
print(re.search('[a-zA-Z]+', mystring))
# Out:
# ['Hi', 'Ram', 'Welcome', 'to', 'Edureka']
# <re.Match object; span=(0, 2), match='Hi'>

# %%
mystring = 'abc_xyz@gmail.com. Please communicate mayank09.parikh@abc.xyz at your convenience. My alternate email id is mayank.parikh@abc.xyz'
#print(re.findall('[a-zA-Z0-9]+[.]*[_0-9a-zA-Z]*@[a-zA-Z]+.[a-zA-Z]+', mystring))  
print(re.findall(r"[a-z0-9\.\-_+]+@[a-z0-9\-+_]+\.[a-z]+", mystring))
# Out:
# ['abc_xyz@gmail.com', 'mayank09.parikh@abc.xyz', 'mayank.parikh@abc.xyz']

# %%
mystring = 'abc_xyz@gmail.com. Please communicate mayank09.parikh@abc.xyz at your convenience. My alternate email id is mayank.parikh@abc.xyz'
#print(re.findall('[a-zA-Z0-9]+[.]*[_0-9a-zA-Z]*@[a-zA-Z]+.[a-zA-Z]+', mystring))  
print(re.findall('[a-z0-9\.\-+@[a-z0-9\.\-+_]+\.[a-z]+', mystring))

# %%
mystring = 'abc_xyz@gmail.com'
#print(re.match('[a-zA-Z]+[_0-9a-zA-Z]*.@[a-zA-Z]+.[a-zA-Z]+', mystring))
print(re.match('[a-zA-Z]+[_0-9a-zA-Z]*.[_0-9a-zA-Z]*@[a-zA-Z]+.[a-zA-Z]+', mystring))

# %%
mystring = 'abc_xyz@gmail.com. Please communicate at your convenience. My alternate email id is mayank09.parikh@abc.xyz'
#mystring = 'abcxyz@gmail.com'
print(re.findall('[a-zA-Z]+[_0-9a-zA-Z]*[.]?[_0-9a-zA-Z]*@[a-zA-Z]+.[a-zA-Z]+', mystring))

# %% [markdown]
# * **For hands on and tutorial:** https://www.w3schools.com/python/python_regex.asp
# * **Very good explanation:** https://realpython.com/regex-python/

# %% [markdown]
# ![download.png](attachment:4aaac839-5299-42c2-8c06-a7f54a8a5089.png)![download.png](attachment:4007ff5e-2bda-484a-8f67-0b89f4d6a670.png)![MetaCharacters.png](attachment:MetaCharacters.png)

# %% [markdown]
# **[ ] -- 	A set of characters**

# %% [markdown]
# **\	--  Signals a special sequence (can also be used to escape special characters)**

# %%
txt = "The rain in Spain"

#Find all lower case characters alphabetically between "a" and "m":

x = re.findall("[a-m]", txt)
print(x)

# %%
txt = "That will be 59 dollars"

#Find all digit characters:

x = re.findall("\d", txt)
print(x)

# %% [markdown]
# **. --	Any character (except newline character)**

# %%
txt = "hello world"

#Search for a sequence that starts with "he", followed by two (any) characters, and an "o":

x = re.findall("he..o", txt)
print(x)

# %% [markdown]
# **^	-- Starts with**

# %%
txt = "hello world"

#Check if the string starts with 'hello':

x = re.findall("^hello", txt)
if x:
  print("Yes, the string starts with 'hello'")
else:
  print("No match")

# %% [markdown]
# **$	-- Ends with**

# %%
txt = "hello world"

#Check if the string ends with 'world':

x = re.findall("world$", txt)
if x:
  print("Yes, the string ends with 'world'")
else:
  print("No match")

# %% [markdown]
# **{} --	Exactly the specified number of occurrences**

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains "a" followed by exactly two "l" characters:

x = re.findall("al{2}", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")

# %% [markdown]
# **|	-- Either or**

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains either "falls" or "stays":

x = re.findall("falls|stays", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")

# %% [markdown]
# ![download.png](attachment:79ce8217-b9c2-448e-8b44-b947afae3ee0.png)![download.png](attachment:f85d4a45-a13b-4d34-bcfa-af999c4a145e.png)![SpecialSequences.png](attachment:SpecialSequences.png)
# ![SpecialSequences2.png](attachment:SpecialSequences2.png)

# %% [markdown]
# ![Set.png](attachment:Set.png)

# %%
mystr1 = 'line1 content. line2 content. line3 content'
mystr2 = 'line1 line2 line3'
print(re.split('\.', mystr1))
print(re.split(' ', mystr2))
# string="She sells. sea shells. on the. sea shore"
# print(re.split(" ",string))

# %% [markdown]
# **\*	-- Zero or more occurrences**

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains "ai" followed by 0 or more "x" characters:

x = re.findall("aix*", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")

# %% [markdown]
# **+	-- One or more occurrences**

# %%
txt = "The rain in Spain falls mainly in the plain!"

#Check if the string contains "ai" followed by 1 or more "x" characters:

x = re.findall("aix+", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
